# %%
# 1pandas部分
import os # 载入读取文件用的模块
os.chdir(r"C:\OneDrive\华莱士\Documents\office培训\PYTHON培训\第五周") # 设置默认目录

import pandas # 载入数据分析模块
df=pandas.read_csv("城市-营运-督导-门店.csv") # 读取文件

def 筛选区域和督导(区域名称,督导名称):
    return df[(df['区域']==区域名称)&(df['督导'].str.contains(督导名称))] # 筛选区域为函数对应的区域名称

# %%
# flask部分
import flask # 导入flask模块
global app # 设置全局变量，这个变量就是网页服务器主程序（可以这样理解）
app=flask.Flask("门店查询") # 这边是给网页服务器取个名字（不影响使用，取什么名字都可以）

@app.route('/') # 设置哪个网址的数据访问什么内容
def 首页():
    return """
<!DOCTYPE html>
<html>
<body>
<form action="/shuchu">
请输入区域名称<br>
<select name="quyu">
<option value="安徽">安徽</option>
<option value="保定">保定</option>
<option value="北京区">北京区</option>
<option value="福州">福州</option>
<option value="广西">广西</option>
<option value="贵州">贵州</option>
<option value="杭绍">杭绍</option>
<option value="河南">河南</option>
<option value="黑龙江">黑龙江</option>
<option value="嘉湖">嘉湖</option>
<option value="江苏">江苏</option>
<option value="金丽衢">金丽衢</option>
<option value="南平三明">南平三明</option>
<option value="宁台区">宁台区</option>
<option value="泉州">泉州</option>
<option value="厦门">厦门</option>
<option value="山东">山东</option>
<option value="山西">山西</option>
<option value="陕西">陕西</option>
<option value="汕头">汕头</option>
<option value="上海">上海</option>
<option value="沈阳">沈阳</option>
<option value="四川">四川</option>
<option value="天津">天津</option>
<option value="温州区">温州区</option>
<option value="云南">云南</option>
<option value="重庆">重庆</option>
<option vblue="安徽">安徽</option>
<option vblue="保定">保定</option>
<option vblue="北京区">北京区</option>
<option vblue="福州">福州</option>
<option vblue="广西">广西</option>
<option vblue="贵州">贵州</option>
<option vblue="杭绍">杭绍</option>
<option vblue="河南">河南</option>
<option vblue="黑龙江">黑龙江</option>
<option vblue="嘉湖">嘉湖</option>
<option vblue="江苏">江苏</option>
<option vblue="金丽衢">金丽衢</option>
<option vblue="南平三明">南平三明</option>
<option vblue="宁台区">宁台区</option>
<option vblue="泉州">泉州</option>
<option vblue="厦门">厦门</option>
<option vblue="山东">山东</option>
<option vblue="山西">山西</option>
<option vblue="陕西">陕西</option>
<option vblue="汕头">汕头</option>
<option vblue="上海">上海</option>
<option vblue="沈阳">沈阳</option>
<option vblue="四川">四川</option>
<option vblue="天津">天津</option>
<option vblue="温州区">温州区</option>
<option vblue="云南">云南</option>
<option vblue="重庆">重庆</option>
<option vclue="安徽">安徽</option>
<option vclue="保定">保定</option>
<option vclue="北京区">北京区</option>
<option vclue="福州">福州</option>
<option vclue="广西">广西</option>
<option vclue="贵州">贵州</option>
<option vclue="杭绍">杭绍</option>
<option vclue="河南">河南</option>
<option vclue="黑龙江">黑龙江</option>
<option vclue="嘉湖">嘉湖</option>
<option vclue="江苏">江苏</option>
<option vclue="金丽衢">金丽衢</option>
<option vclue="南平三明">南平三明</option>
<option vclue="宁台区">宁台区</option>
<option vclue="泉州">泉州</option>
<option vclue="厦门">厦门</option>
<option vclue="山东">山东</option>
<option vclue="山西">山西</option>
<option vclue="陕西">陕西</option>
<option vclue="汕头">汕头</option>
<option vclue="上海">上海</option>
<option vclue="沈阳">沈阳</option>
<option vclue="四川">四川</option>
<option vclue="天津">天津</option>
<option vclue="温州区">温州区</option>
<option vclue="云南">云南</option>
<option vclue="重庆">重庆</option>

</select>
<br>请输入督导名称<br>
<input type="text" name="dudao" value="Mouse">
<br><br>
<input type="submit" value="Submit">
</form> 
<!-- CSS only -->
<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/css/bootstrap.min.css" integrity="sha384-9aIt2nRpC12Uk9gS9baDl411NQApFmC26EwAOH8WgZl5MYYxFfc+NcPb1dKGj7Sk" crossorigin="anonymous">

<!-- JS, Popper.js, and jQuery -->
<script src="https://cdn.jsdelivr.net/npm/jquery@3.5.1/dist/jquery.slim.min.js" integrity="sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj" crossorigin="anonymous"></script>
<script src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" crossorigin="anonymous"></script>
<script src="https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.min.js" integrity="sha384-OgVRvuATP1z7JjHLkuOU7Xw704+h835Lr+6QL9UvYjZE3Ipu6Tp75j7Bh/kR0JKI" crossorigin="anonymous"></script>
</body>
</html>
"""

@app.route('/shuchu') # 设置哪个网址的数据访问什么内容
def 输出():
    quyu = flask.request.args.get('quyu') # 获取  get  参数，了解网页查询的是哪个区域
    dudao = flask.request.args.get('dudao') # 获取  get  参数，了解网页在查询哪个督导  
    return 筛选区域和督导(区域名称=quyu,督导名称=dudao).to_html(classes="table table-striped") + """<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/css/bootstrap.min.css" integrity="sha384-9aIt2nRpC12Uk9gS9baDl411NQApFmC26EwAOH8WgZl5MYYxFfc+NcPb1dKGj7Sk" crossorigin="anonymous">

<!-- JS, Popper.js, and jQuery -->
<script src="https://cdn.jsdelivr.net/npm/jquery@3.5.1/dist/jquery.slim.min.js" integrity="sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj" crossorigin="anonymous"></script>
<script src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" crossorigin="anonymous"></script>
<script src="https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.min.js" integrity="sha384-OgVRvuATP1z7JjHLkuOU7Xw704+h835Lr+6QL9UvYjZE3Ipu6Tp75j7Bh/kR0JKI" crossorigin="anonymous"></script>
""" # 用刚刚写好的筛选区域的函数，来筛选区域

app.run()
# Out:
#  * Serving Flask app "门店查询" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [17/Jul/2020 17:05:02] "GET /shuchu?quyu=安徽&dudao=刘 HTTP/1.1" 200 -

# %%
df[df['门店名称']=='长***宁'] #筛选门店
df[df['督导']=='刘***'] #筛选督导
df[df['城市经理']=='刘***'] # 筛选城市经理
df[df['区域']=='南平三明'] # 筛选区域为南平三明

筛选区域('上海')

df.tail(10) # 查看最末位10条数据
